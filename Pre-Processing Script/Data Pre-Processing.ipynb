# %%
import json
import emoji
from datetime import datetime, timedelta
from timezonefinder import TimezoneFinder
import pytz
import re
from geopy.geocoders import Nominatim
from geopy.exc import GeocoderTimedOut
from geopy.exc import GeocoderUnavailable
import ssl
import certifi
import geopy.geocoders
from time import sleep
from nltk import bigrams
import sys
import time 

ctx = ssl.create_default_context(cafile=certifi.where())
geopy.geocoders.options.default_ssl_context = ctx


class FilteredTweet:  # Class to store the clean Tweet data.
    def __init__(self, tweet_dict, list_sleep_words, list_sleep_bigrams, list_stress_words):
        self.index = None
        localtime = parseDate(tweet_dict)
        self.tweet_weekday = localtime.weekday()
        self.tweet_day = localtime.day
        self.tweet_hour = localtime.hour
        self.tweet_year = localtime.year
        self.orig_text = tweet_dict['text']
        self.filtered_text = parseTweetText(tweet_dict, list_sleep_words, list_sleep_bigrams, list_stress_words)

        self.user_ID = tweet_dict['user']['id']
        self.user_verified = tweet_dict['user']['verified']
        self.user_followers_count = tweet_dict['user']['followers_count']
        self.user_friends_count = tweet_dict['user']['friends_count']
        self.user_listed_count = tweet_dict['user']['listed_count']
        self.user_statuses_count = tweet_dict['user']['statuses_count']

        user_creation_time = datetime.strptime(tweet_dict['user']['created_at'], '%a %b %d %H:%M:%S +0000 %Y')
        self.user_creation_year = user_creation_time.year
        self.user_creation_month = user_creation_time.month
        self.user_creation_day = user_creation_time.day

        self.place_name = tweet_dict['place']['name']

        city_and_province = tweet_dict['place']['full_name'].split(",")
        if len(city_and_province) > 1:
            self.place_province = city_and_province[1].strip()
        else:
            self.place_province = None

        self.place_country = tweet_dict['place']['country']
        self.place_longitude = float(tweet_dict['place']['bounding_box']['coordinates'][0][0][0])
        self.place_latitude = float(tweet_dict['place']['bounding_box']['coordinates'][0][0][1])
        
        tweet_date = datetime.strptime(tweet_dict["created_at"], '%a %b %d %H:%M:%S +0000 %Y')
        elapsed_time = tweet_date - user_creation_time
        self.elapsed_time_in_days = elapsed_time/timedelta(minutes=1)/60/24

            
        self.label = None 

    def __str__(self):  # Represent the tweet as a dictionary.
        return str(self.__dict__)


    def setIndex(
            self, the_index):  # Method will set the index.  Called when new clean tweet is written.
        self.index = the_index


def filterCountry(tweet_dict, country):  # Filter tweet object based on country.  Takes arguments of a standard tweet
    # dictionary and country (as string).
    if 'place' in tweet_dict.keys():
        if tweet_dict['place'] is not None:
            if 'country' in tweet_dict['place'].keys():
                if tweet_dict['place']['country'] == country:
                    return True
                else:
                    return False
            else:
                return False
        else:
            return False
    else:
        return False


def filterTrackable(tweet_dict):  # Filter tweet based on whether it is trackable or not.
    if parseTimeZone(tweet_dict) is not None:
        return True
    else:
        return False


def filterLanguage(tweet_dict, language):  # Filter tweet object based on language.
    if 'lang' in tweet_dict.keys():
        if tweet_dict['lang'] is not None:
            if tweet_dict['lang'] == language:
                return True
            else:
                return False
        else:
            return False
    else:
        return False


def filterOriginal(tweet_dict):  # Method to filter out tweets that are quotes or re-tweets.
    if 'is_quote_status' in tweet_dict.keys():
        if tweet_dict['is_quote_status']:
            return False
    if tweet_dict['retweeted']:
        return False
    else:
        return True


def parseDate(tweet_dict):  # Method to parse the date/time of a tweet into the tweeter's local time.
    date_info = tweet_dict['created_at']
    orig_date = datetime.strptime(date_info, '%a %b %d %H:%M:%S +0000 %Y')
    fmt = '%a, %b %d %Y %H:%M:%S'
    new_date = datetime.strptime(datetime.strftime(orig_date, fmt), fmt)
    tz = parseTimeZone(tweet_dict)
    localized_time = new_date.astimezone(pytz.timezone(tz))
    offset = int(str(localized_time)[-6:-3])
    delta = timedelta(hours=offset)
    localized_time = new_date + delta
    return localized_time


def parseTimeZone(tweet_dict):  # Method to retrieve the timezone based on the user coordinates.
    tf = TimezoneFinder()
    if 'place' in tweet_dict.keys():
        if tweet_dict['place'] is not None:
            if 'bounding_box' in tweet_dict['place'].keys():
                if 'coordinates' in tweet_dict['place']['bounding_box'].keys():
                    if len(tweet_dict['place']['bounding_box']['coordinates']) > 0:
                        longitude = float(tweet_dict['place']['bounding_box']['coordinates'][0][0][0])
                        latitude = float(tweet_dict['place']['bounding_box']['coordinates'][0][0][1])
                        timezone = tf.timezone_at(lat=latitude, lng=longitude)
                        if timezone is None:
                            timezone = tf.closest_timezone_at(lat=latitude, lng=longitude)
                        return timezone
                    else:
                        return None
                else:
                    return None
            else:
                return None
        else:
            return None
    else:
        return None


def filterTweet(tweet_dict, language, country):  # Apply language, original, country, and trackable filters to a tweet.
    return (filterCountry(tweet_dict, country) and filterLanguage(tweet_dict, language)
            and filterOriginal(tweet_dict) and filterTrackable(tweet_dict))


def is_emoji(s):  # Method to check if a string is an emoji.
    return s in emoji.UNICODE_EMOJI


def add_space(text):  # Method to add a space between word-emoji pairs.
    result = ''
    for char in text:
        if is_emoji(char):
            char = 'emoji_'+ char + " "
            result += ' '
        result += char
    return result.strip()


def parseTweetText(tweetDict, list_sleep_words, list_sleep_bigrams, list_stress_words):  # Method to demojize tweet text, URLs, remove punctuation, and move to lowercase.
    tweet_text = tweetDict["text"]
    tweet_text = tweet_text + " ."
    tweet_text = tweet_text.replace('&amp;', " and ")
    tweet_text = tweet_text.replace('+', " ")
    tweet_text = tweet_text.replace('=', " ")
    tweet_text = tweet_text.replace('\n', " ")
    tweet_text = tweet_text.replace('@', " AT_")
    tweet_text = tweet_text.replace('#', " ")
    tweet_text = tweet_text.replace('-', " ")
    tweet_text = tweet_text.replace('\'', "")
    tweet_text = add_space(tweet_text)
    tweet_text = emoji.demojize(tweet_text)
    
    filtered_words_1 = []
    clean_words_1 = []
    
    for word in re.split(' +', tweet_text):
        if word.startswith('https'):
            continue
        else:
            word = word.lower()
            word = word.replace("\\", " and ")
            word = word.replace("\/", " and ")
            word = re.sub(r'[^a-z0-9\s_]', ' ', word)
            word = word.strip()
            clean_words_1.append(word)
    clean_sentence_1 = ' '.join(clean_words_1)
    clean_words_2 = re.split(' +', clean_sentence_1)
    for word in clean_words_2:
        while (word.startswith(" ") or word.endswith(" ")):
            word = word.strip()
        while (word.startswith("_") or word.endswith("_")):
            word = word.strip("_")
    
    if (checkSleepWords(clean_words_2, list_sleep_words, list_sleep_bigrams) or checkStressWords(clean_words_2, list_stress_words)):
        for word in re.split(' +', tweet_text):
            if word.startswith('https'):
                continue
            else:
                word = word.lower()
                word = word.replace("\\", " and ")
                word = word.replace("\/", " and ")
                word = re.sub(r'[^a-z0-9\s.,:;!?_]', '', word)
                word = word.strip()
                filtered_words_1.append(word)
        filtered_sentence_1 = ' '.join(filtered_words_1)
        filtered_words_2 = []
        filtered_sentence_2 = negation_sub(filtered_sentence_1)
        for word in re.split(' +', filtered_sentence_2):
            word = re.sub(r'[.,:;!?]', ' ', word)
            while (word.startswith(" ") or word.endswith(" ")):
                word = word.strip()
            while (word.startswith("_") or word.endswith("_")):
                word = word.strip("_")
            if (word != ""):
                filtered_words_2.append(word)
        last_filtered =  ' '.join(filtered_words_2)
        last_filtered = last_filtered.replace("emoji_ ", "emoji_")
        return last_filtered
    else:
        return None 


def negation_sub(text):
    transformed = re.sub(r'\b(?:not|no|never|aint|doesnt|havent|lacks|none|mightnt|shouldnt|'
                         r'cannot|dont|neither|nor|mustnt|wasnt|cant|hadnt|isnt|neednt|without|'
                         r'darent|hardly|lack|nothing|oughtnt|wouldnt|didnt|hasnt|lacking|nobody|'
                         r'nowhere|shant)\b[\w\s]+[.,:;!?]',
                         lambda match: re.sub(r'(\s+)(\w+)', r'\1NEG_\2', match.group(0)),
                         text,
                         flags=re.IGNORECASE)
    return transformed


def checkSleepWords(list_words_to_check, list_sleep_words,
                    list_sleep_bigrams):  # Method to check for existence of sleep keywords/bigrams in filtered text.
    # Takes a list of words to check, list of sleep words, and list of sleep bigrams to compare to.
    tweet_dict_bigrams = list(bigrams(list_words_to_check))
    for word in list_words_to_check:
        if word in list_sleep_words:
            return True

    for each_bigram in tweet_dict_bigrams:
        for sleep_bigram in list_sleep_bigrams:
            if sleep_bigram[0] == each_bigram[0] and sleep_bigram[1] == each_bigram[0]:
                return True
    return False


def checkStressWords(list_words_to_check,
                     list_stress_words):  # Method to check for existence of stress keywords in filtered text.
    # Takes a list of words to check and a list of stress words to compare to.
    for word in list_words_to_check:
        if word in list_stress_words:
            return True
    return False

list_sleep_words = ["bed", "sleep", "sack", "insomnia", "dodo", "zzz", "siesta", "tired", "nosleep",
                    "cantsleep", "rest", "asleep", "slept", "sleeping", "sleepy",
                    "ambien", "zolpidem", "lunesta", "intermezzo", "trazadone", "eszopiclone",
                    "zaleplon"]  # List of sleep words to check for.
list_sleep_bigrams = [["pass", "out"], ["get", "up"], ["wake", "up"],
                      ["power", "nap"]]  # List of sleep bigrams to compare tweet text to.
list_stress_words = ["heart", "control", "depression", "disease", "study", "studies", "life", "stressor", "body", "stress",
                     "anxiety", "health", "feel", "pain","social", "stressors", "pressure", "work", "risk", "stressful", "busy",
                     "depressed", "nervous", "university", "cancer", "marry", "wedding", "bride", "income", "salary", "rent", 
                     "hospital", "sick", "school", "holiday", "finals", "born", "baby", "life", "fired", "job", "lose", "cold",
                     "war", "quarrel", "argue", "question", "blame", "afraid", "baby", "pregnant", "mother-to-be", 
                     "revise", "habits", "smoke", "drink", "pass", "away", "RIP", "divorce", "ex-wife", "cry","surgery"]  # List of stress keywords to compare tweet text to.

class Logger(object):
    def __init__(self, file_name):
        self.terminal = sys.stdout
        self.log = open(file_name, "w")

    def write(self, message):
        self.terminal.write(message)
        self.log.write(message)  

    def flush(self):
        #this flush method is needed for python 3 compatibility.
        #this handles the flush command by doing nothing.
        #you might want to specify some extra behavior here.
        pass    

start_time = time.time()
   
    
sys.stdout = Logger("iterative_test_2.txt")
index_clean = 1
filename = "/home/cheunw/Group Project Folder/Project Raw Data Files/2.json"  # Name of .json dataset to pass.  Should have 1 tweet per line of file.
output_filename = "iterative_output_test_2.json"  # Name of clean .json file to write to.  Will have 1 clean tweet per line of file.

print("Beginning processing...")

with open(filename, 'r', encoding='utf8', errors='ignore') as f:  # Open input file
    with open(output_filename, 'w', encoding='utf8') as outputFile:  # Open output file
        for (i, line) in enumerate(f, 1):  # Iterate through each line in input file.
            tweet_dict = json.loads(line)  # Load the .json object into a dictionary.
            try:
                if filterTweet(tweet_dict, "en", "Canada"):  # Filter the tweet.
                    new_tweet = FilteredTweet(tweet_dict, list_sleep_words, list_sleep_bigrams, list_stress_words)  # Create a new filtered tweet.
                    if new_tweet.filtered_text is None:
                        continue
                    else:
                        new_tweet.setIndex(index_clean)  # Set the index.
                        new_tweet_json = json.dumps(
                            new_tweet.__dict__)  # Create a new json object from the clean tweet.
                        clean_tweet_json = json.dumps(new_tweet.__dict__, indent=4)
                        print(clean_tweet_json)
                        outputFile.write(new_tweet_json)  # Write the new json object to the output file.
                        outputFile.write('\n')  # Write a newline to separate tweets in output file.
                        print("Current tweets written from file:", index_clean, ", Total Tweets evaluated from file:", i)
                        index_clean += 1
            except:
                print("Encountered error in line", i, ": skipping this line.")
                continue


print("****************************************")
print("Total clean tweets written from file: ", index_clean-1)
print("Total tweets evaluated from file: ", i)
end_time = time.time()
print("Time of execution in seconds:", end_time - start_time)
# Out:
# Beginning processing...
# {
#     "index": 1,
#     "tweet_weekday": 5,
#     "tweet_day": 29,
#     "tweet_hour": 21,
#     "tweet_year": 2018,
#     "orig_text": "@thechadrsmith Hahaha too much salt in your diet is bad for your health you big bitch lol",
#     "filtered_text": "at_thechadrsmith hahaha too much salt in your diet is bad for your health you big bitch lol",
#     "user_ID": 104688908,
#     "user_verified": false,
#     "user_followers_count": 284,
#     "user_friends_count": 659,
#     "user_listed_count": 3,
#     "user_statuses_count": 1988,
#     "user_creation_year": 2010,
#     "user_creation_month": 1,
#     "user_creation_day": 14,
#     "place_name": "Peterborough",
#     "place_province": "Ontario",
#     "place_country": "Canada",
#     "place_longitude": -78.387994,
#     "place_latitude": 44.252035,
#     "elapsed_time_in_days": 3271.9699652777776,
#     "label": null
# }
# Current tweets written from file: 1 , Total Tweets evaluated from file: 1188
# {
#     "index": 2,
#     "tweet_weekday": 5,
#     "tweet_day": 29,
#     "tweet_hour": 21,
#     "tweet_year": 2018,
#     "orig_text": "@BrotherShaunEPB There's a man in our local bar in Oakville, Ontario singing No Woman No Cry and not appreciating u\u2026 https://t.co/HR5u3H6BEq",
#     "filtered_text": "at_brothershaunepb theres a man in our local bar in oakville ontario singing no NEG_woman NEG_no NEG_cry NEG_and NEG_not NEG_appreciating NEG_u",
#     "user_ID": 261485316,
#     "user_verified": false,
#     "user_followers_count": 49,
#     "user_friends_count": 90,
#     "user_listed_count": 4,
#     "user_statuses_count": 857,
#     "user_creation_year": 2011,
#     "user_creation_month": 3,
#     "user_creation_day": 6,
#     "place_name": "Oakville",
#     "place_province": "Ontario",
#     "place_country": "Canada",
#     "place_longitude": -79.810961,
#     "place_latitude": 43.309929,
#     "elapsed_time_in_days": 2856.0016319444444,
#     "label": null
# }
# Current tweets written from file: 2 , Total Tweets evaluated from file: 2147
# {
#     "index": 3,
#     "tweet_weekday": 5,
#     "tweet_day": 29,
#     "tweet_hour": 18,
#     "tweet_year": 2018,
#     "orig_text": "@KellyannePolls Rest in Peace Bre.",
#     "filtered_text": "at_kellyannepolls rest in peace bre",
#     "user_ID": 269286279,
#     "user_verified": false,
#     "user_followers_count": 1265,
#     "user_friends_count": 1624,
#     "user_listed_count": 0,
#     "user_statuses_count": 32573,
#     "user_creation_year": 2011,
#     "user_creation_month": 3,
#     "user_creation_day": 20,
#     "place_name": "Richmond",
#     "place_province": "British Columbia",
#     "place_country": "Canada",
#     "place_longitude": -123.304549,
#     "place_latitude": 49.08609,
#     "elapsed_time_in_days": 2841.5299189814814,
#     "label": null
# }
# Current tweets written from file: 3 , Total Tweets evaluated from file: 2549
# {
#     "index": 4,
#     "tweet_weekday": 5,
#     "tweet_day": 29,
#     "tweet_hour": 18,
#     "tweet_year": 2018,
#     "orig_text": "At some point in life, you have to grow up and stop wearing a torque as part of your wardrobe. Throw out the damn t\u2026 https://t.co/ut0vdQmCWW",
#     "filtered_text": "at some point in life you have to grow up and stop wearing a torque as part of your wardrobe throw out the damn t",
#     "user_ID": 240555023,
#     "user_verified": false,
#     "user_followers_count": 821,
#     "user_friends_count": 1031,
#     "user_listed_count": 19,
#     "user_statuses_count": 13111,
#     "user_creation_year": 2011,
#     "user_creation_month": 1,
#     "user_creation_day": 20,
#     "place_name": "North Vancouver",
#     "place_province": "British Columbia",
#     "place_country": "Canada",
#     "place_longitude": -123.128272,
#     "place_latitude": 49.293965,
#     "elapsed_time_in_days": 2900.851909722222,
#     "label": null
# }
# Current tweets written from file: 4 , Total Tweets evaluated from file: 5964
# {
#     "index": 5,
#     "tweet_weekday": 5,
#     "tweet_day": 29,
#     "tweet_hour": 18,
#     "tweet_year": 2018,
#     "orig_text": "@tincupsdad @Ben10133400 @celeste43_ @darrenrovell Not saying he should not  get paid for his work. Just saying be\u2026 https://t.co/TWTP4UTQFS",
#     "filtered_text": "at_tincupsdad at_ben10133400 at_celeste43 at_darrenrovell not NEG_saying NEG_he NEG_should NEG_not NEG_get NEG_paid NEG_for NEG_his NEG_work just saying be",
#     "user_ID": 224065912,
#     "user_verified": false,
#     "user_followers_count": 712,
#     "user_friends_count": 234,
#     "user_listed_count": 18,
#     "user_statuses_count": 1314,
#     "user_creation_year": 2010,
#     "user_creation_month": 12,
#     "user_creation_day": 8,
#     "place_name": "Richmond",
#     "place_province": "British Columbia",
#     "place_country": "Canada",
#     "place_longitude": -123.304549,
#     "place_latitude": 49.08609,
#     "elapsed_time_in_days": 2943.999074074074,
#     "label": null
# }
# Current tweets written from file: 5 , Total Tweets evaluated from file: 6414
# {
#     "index": 6,
#     "tweet_weekday": 5,
#     "tweet_day": 29,
#     "tweet_hour": 21,
#     "tweet_year": 2018,
#     "orig_text": "@camille123peace It means my love/ my dear. Pretty much used as baby",
#     "filtered_text": "at_camille123peace it means my love my dear pretty much used as baby",
#     "user_ID": 636561687,
#     "user_verified": false,
#     "user_followers_count": 48,
#     "user_friends_count": 208,
#     "user_listed_count": 0,
#     "user_statuses_count": 74,
#     "user_creation_year": 2012,
#     "user_creation_month": 7,
#     "user_creation_day": 15,
#     "place_name": "Oakville",
#     "place_province": "Ontario",
#     "place_country": "Canada",
#     "place_longitude": -79.810961,
#     "place_latitude": 43.309929,
#     "elapsed_time_in_days": 2358.18162037037,
#     "label": null
# }
# Current tweets written from file: 6 , Total Tweets evaluated from file: 7971
# {
#     "index": 7,
#     "tweet_weekday": 5,
#     "tweet_day": 29,
#     "tweet_hour": 19,
#     "tweet_year": 2018,
#     "orig_text": "Cold snowy night in the rail yard. @ Edmonton, Alberta https://t.co/NfWilhVc63",
#     "filtered_text": "cold snowy night in the rail yard at edmonton alberta",
#     "user_ID": 16478408,
#     "user_verified": false,
#     "user_followers_count": 84,
#     "user_friends_count": 189,
#     "user_listed_count": 3,
#     "user_statuses_count": 509,
#     "user_creation_year": 2008,
#     "user_creation_month": 9,
#     "user_creation_day": 27,
#     "place_name": "Edmonton",
#     "place_province": "Alberta",
#     "place_country": "Canada",
#     "place_longitude": -113.71368,
#     "place_latitude": 53.395531,
#     "elapsed_time_in_days": 3746.048726851852,
#     "label": null
# }
# Current tweets written from file: 7 , Total Tweets evaluated from file: 9888
# {
#     "index": 8,
#     "tweet_weekday": 5,
#     "tweet_day": 29,
#     "tweet_hour": 18,
#     "tweet_year": 2018,
#     "orig_text": "@tedlieu One of the models, Canadian-born Rachel Blais, offered up documentation to the magazine to support her cla\u2026 https://t.co/V25tByyuLb",
#     "filtered_text": "at_tedlieu one of the models canadian born rachel blais offered up documentation to the magazine to support her cla",
#     "user_ID": 951936094022516700,
#     "user_verified": false,
#     "user_followers_count": 2769,
#     "user_friends_count": 4725,
#     "user_listed_count": 13,
#     "user_statuses_count": 17286,
#     "user_creation_year": 2018,
#     "user_creation_month": 1,
#     "user_creation_day": 12,
#     "place_name": "Vancouver",
#     "place_province": "British Columbia",
#     "place_country": "Canada",
#     "place_longitude": -123.224215,
#     "place_latitude": 49.19854,
#     "elapsed_time_in_days": 351.17446759259263,
#     "label": null
# }
# Current tweets written from file: 8 , Total Tweets evaluated from file: 11398
# {
#     "index": 9,
#     "tweet_weekday": 5,
#     "tweet_day": 29,
#     "tweet_hour": 21,
#     "tweet_year": 2018,
#     "orig_text": "Social worker leaves behind $11m for children's charities. https://t.co/tlAb4a8wFM",
#     "filtered_text": "social worker leaves behind 11m for childrens charities",
#     "user_ID": 1027677408,
#     "user_verified": false,
#     "user_followers_count": 1581,
#     "user_friends_count": 4999,
#     "user_listed_count": 249,
#     "user_statuses_count": 47598,
#     "user_creation_year": 2012,
#     "user_creation_month": 12,
#     "user_creation_day": 22,
#     "place_name": "Mont-Royal",
#     "place_province": "Qu\u00e9bec",
#     "place_country": "Canada",
#     "place_longitude": -73.685994,
#     "place_latitude": 45.48359,
#     "elapsed_time_in_days": 2198.93212962963,
#     "label": null
# }
# Current tweets written from file: 9 , Total Tweets evaluated from file: 11484
# {
#     "index": 10,
#     "tweet_weekday": 5,
#     "tweet_day": 29,
#     "tweet_hour": 18,
#     "tweet_year": 2018,
#     "orig_text": "@Brent_Ashby Negative Brent ... sadly this my last game live . Tsn for the rest . R u here ?",
#     "filtered_text": "at_brent_ashby negative brent sadly this my last game live tsn for the rest r u here",
#     "user_ID": 384606809,
#     "user_verified": false,
#     "user_followers_count": 280,
#     "user_friends_count": 253,
#     "user_listed_count": 3,
#     "user_statuses_count": 888,
#     "user_creation_year": 2011,
#     "user_creation_month": 10,
#     "user_creation_day": 4,
#     "place_name": "Vancouver",
#     "place_province": "British Columbia",
#     "place_country": "Canada",
#     "place_longitude": -123.224215,
#     "place_latitude": 49.19854,
#     "elapsed_time_in_days": 2644.0690509259257,
#     "label": null
# }
# Current tweets written from file: 10 , Total Tweets evaluated from file: 12446
# {
#     "index": 11,
#     "tweet_weekday": 5,
#     "tweet_day": 29,
#     "tweet_hour": 19,
#     "tweet_year": 2018,
#     "orig_text": "New bed+new PJs+fighting a cold=staying inside all day reading, resting &amp; watching hockey! @ Calgary, Alberta https://t.co/o6Yt2SuE0p",
#     "filtered_text": "new bed new pjs fighting a cold staying inside all day reading resting and watching hockey at calgary alberta",
#     "user_ID": 429506524,
#     "user_verified": false,
#     "user_followers_count": 4675,
#     "user_friends_count": 2513,
#     "user_listed_count": 271,
#     "user_statuses_count": 69007,
#     "user_creation_year": 2011,
#     "user_creation_month": 12,
#     "user_creation_day": 6,
#     "place_name": "Calgary",
#     "place_province": "Alberta",
#     "place_country": "Canada",
#     "place_longitude": -114.316038,
#     "place_latitude": 50.84278,
#     "elapsed_time_in_days": 2581.0085069444444,
#     "label": null
# }
# Current tweets written from file: 11 , Total Tweets evaluated from file: 12685
# {
#     "index": 12,
#     "tweet_weekday": 5,
#     "tweet_day": 29,
#     "tweet_hour": 21,
#     "tweet_year": 2018,
#     "orig_text": "Funny how life works man.. \ud83d\ude0c\ud83e\udd70",
#     "filtered_text": "funny how life works man emoji_relieved_face",
#     "user_ID": 557154761,
#     "user_verified": false,
#     "user_followers_count": 477,
#     "user_friends_count": 431,
#     "user_listed_count": 2,
#     "user_statuses_count": 14843,
#     "user_creation_year": 2012,
#     "user_creation_month": 4,
#     "user_creation_day": 18,
#     "place_name": "Toronto",
#     "place_province": "Ontario",
#     "place_country": "Canada",
#     "place_longitude": -79.639319,
#     "place_latitude": 43.403221,
#     "elapsed_time_in_days": 2446.2687499999997,
#     "label": null
# }
# Current tweets written from file: 12 , Total Tweets evaluated from file: 13080
# {
#     "index": 13,
#     "tweet_weekday": 5,
#     "tweet_day": 29,
#     "tweet_hour": 18,
#     "tweet_year": 2018,
#     "orig_text": "In Canada we fire politicians who can\u2019t pass a budget. All of them. Just saying. #GovernmentShutdown",
#     "filtered_text": "in canada we fire politicians who cant NEG_pass NEG_a NEG_budget all of them just saying governmentshutdown",
#     "user_ID": 16172327,
#     "user_verified": false,
#     "user_followers_count": 1648,
#     "user_friends_count": 2160,
#     "user_listed_count": 152,
#     "user_statuses_count": 15318,
#     "user_creation_year": 2008,
#     "user_creation_month": 9,
#     "user_creation_day": 7,
#     "place_name": "Comox Valley A",
#     "place_province": "British Columbia",
#     "place_country": "Canada",
#     "place_longitude": -125.164084,
#     "place_latitude": 49.404858,
#     "elapsed_time_in_days": 3765.303159722222,
#     "label": null
# }
# Current tweets written from file: 13 , Total Tweets evaluated from file: 13245
# {
#     "index": 14,
#     "tweet_weekday": 5,
#     "tweet_day": 29,
#     "tweet_hour": 21,
#     "tweet_year": 2018,
#     "orig_text": "@JThomasAlbert @StefanMolyneux Thomas wants to be a #Wizard as well. Magic thoughts and words don't work here\u2026 https://t.co/650HXG9Ms5",
#     "filtered_text": "at_jthomasalbert at_stefanmolyneux thomas wants to be a wizard as well magic thoughts and words dont NEG_work NEG_here",
#     "user_ID": 1040616468231192600,
#     "user_verified": false,
#     "user_followers_count": 1515,
#     "user_friends_count": 2304,
#     "user_listed_count": 1,
#     "user_statuses_count": 17473,
#     "user_creation_year": 2018,
#     "user_creation_month": 9,
#     "user_creation_day": 14,
#     "place_name": "Toronto",
#     "place_province": "Ontario",
#     "place_country": "Canada",
#     "place_longitude": -79.639319,
#     "place_latitude": 43.403221,
#     "elapsed_time_in_days": 106.46374999999999,
#     "label": null
# }
# Current tweets written from file: 14 , Total Tweets evaluated from file: 13599
# {
#     "index": 15,
#     "tweet_weekday": 5,
#     "tweet_day": 29,
#     "tweet_hour": 21,
#     "tweet_year": 2018,
#     "orig_text": "Our beautiful border collie pups, week 1, 2, 3 &amp; 4. This is Ziggy, who fit into my palm when born, and now hangs ha\u2026 https://t.co/66pnBOdbqn",
#     "filtered_text": "our beautiful border collie pups week 1 2 3 and 4 this is ziggy who fit into my palm when born and now hangs ha",
#     "user_ID": 1008343563485130800,
#     "user_verified": false,
#     "user_followers_count": 12,
#     "user_friends_count": 30,
#     "user_listed_count": 0,
#     "user_statuses_count": 71,
#     "user_creation_year": 2018,
#     "user_creation_month": 6,
#     "user_creation_day": 17,
#     "place_name": "Tweed",
#     "place_province": "Ontario",
#     "place_country": "Canada",
#     "place_longitude": -77.568214,
#     "place_latitude": 44.349357,
#     "elapsed_time_in_days": 195.520625,
#     "label": null
# }
# Current tweets written from file: 15 , Total Tweets evaluated from file: 16335
# {
#     "index": 16,
#     "tweet_weekday": 5,
#     "tweet_day": 29,
#     "tweet_hour": 19,
#     "tweet_year": 2018,
#     "orig_text": "i see brad marchand is teaching the rest of the bruins how to slewfoot too",
#     "filtered_text": "i see brad marchand is teaching the rest of the bruins how to slewfoot too",
#     "user_ID": 46845367,
#     "user_verified": false,
#     "user_followers_count": 485,
#     "user_friends_count": 387,
#     "user_listed_count": 33,
#     "user_statuses_count": 18516,
#     "user_creation_year": 2009,
#     "user_creation_month": 6,
#     "user_creation_day": 13,
#     "place_name": "Edmonton",
#     "place_province": "Alberta",
#     "place_country": "Canada",
#     "place_longitude": -113.71368,
#     "place_latitude": 53.395531,
#     "elapsed_time_in_days": 3486.7946875,
#     "label": null
# }
# Current tweets written from file: 16 , Total Tweets evaluated from file: 18231
# {
#     "index": 17,
#     "tweet_weekday": 5,
#     "tweet_day": 29,
#     "tweet_hour": 18,
#     "tweet_year": 2018,
#     "orig_text": "@CraigCameronWV @robert_billard I don\u2019t think it\u2019s the city\u2019s job to pick winners &amp; losers. Can regulate size of st\u2026 https://t.co/q3OYFG2Qt1",
#     "filtered_text": "at_craigcameronwv at_robert_billard i dont NEG_think NEG_its NEG_the NEG_citys NEG_job NEG_to NEG_pick NEG_winners NEG_and NEG_losers can regulate size of st",
#     "user_ID": 8528652,
#     "user_verified": false,
#     "user_followers_count": 2083,
#     "user_friends_count": 1855,
#     "user_listed_count": 76,
#     "user_statuses_count": 20209,
#     "user_creation_year": 2007,
#     "user_creation_month": 8,
#     "user_creation_day": 30,
#     "place_name": "Vancouver",
#     "place_province": "British Columbia",
#     "place_country": "Canada",
#     "place_longitude": -123.224215,
#     "place_latitude": 49.19854,
#     "elapsed_time_in_days": 4139.803506944444,
#     "label": null
# }
# Current tweets written from file: 17 , Total Tweets evaluated from file: 18241
# {
#     "index": 18,
#     "tweet_weekday": 5,
#     "tweet_day": 29,
#     "tweet_hour": 21,
#     "tweet_year": 2018,
#     "orig_text": "Tell me why I\u2019m such a nervous fucking anxious stupid asshole",
#     "filtered_text": "tell me why im such a nervous fucking anxious stupid asshole",
#     "user_ID": 455916787,
#     "user_verified": false,
#     "user_followers_count": 472,
#     "user_friends_count": 211,
#     "user_listed_count": 6,
#     "user_statuses_count": 44394,
#     "user_creation_year": 2012,
#     "user_creation_month": 1,
#     "user_creation_day": 5,
#     "place_name": "Oshawa",
#     "place_province": "Ontario",
#     "place_country": "Canada",
#     "place_longitude": -78.959206,
#     "place_latitude": 43.614586,
#     "elapsed_time_in_days": 2550.3654050925925,
#     "label": null
# }
# Current tweets written from file: 18 , Total Tweets evaluated from file: 18396
# {
#     "index": 19,
#     "tweet_weekday": 5,
#     "tweet_day": 29,
#     "tweet_hour": 21,
#     "tweet_year": 2018,
#     "orig_text": "@deadxtired Put that away before you get hurt",
#     "filtered_text": "at_deadxtired put that away before you get hurt",
#     "user_ID": 112920916,
#     "user_verified": false,
#     "user_followers_count": 418,
#     "user_friends_count": 1393,
#     "user_listed_count": 3,
#     "user_statuses_count": 13165,
#     "user_creation_year": 2010,
#     "user_creation_month": 2,
#     "user_creation_day": 10,
#     "place_name": "Kingston",
#     "place_province": "Ontario",
#     "place_country": "Canada",
#     "place_longitude": -76.712759,
#     "place_latitude": 44.16054,
#     "elapsed_time_in_days": 3244.927002314815,
#     "label": null
# }
# Current tweets written from file: 19 , Total Tweets evaluated from file: 18429
# {
#     "index": 20,
#     "tweet_weekday": 5,
#     "tweet_day": 29,
#     "tweet_hour": 18,
#     "tweet_year": 2018,
#     "orig_text": "See our latest BC, Canada job and click to apply: Specialist I, Clinical Application - SCI - https://t.co/7DYkCWNe1n medicaldevices veterans",
#     "filtered_text": "see our latest bc canada job and click to apply specialist i clinical application sci medicaldevices veterans",
#     "user_ID": 256780228,
#     "user_verified": false,
#     "user_followers_count": 963,
#     "user_friends_count": 82,
#     "user_listed_count": 179,
#     "user_statuses_count": 829,
#     "user_creation_year": 2011,
#     "user_creation_month": 2,
#     "user_creation_day": 24,
#     "place_name": "Bulkley-Nechako G",
#     "place_province": "British Columbia",
#     "place_country": "Canada",
#     "place_longitude": -128.48587,
#     "place_latitude": 53.660186,
#     "elapsed_time_in_days": 2866.0058680555558,
#     "label": null
# }
# Current tweets written from file: 20 , Total Tweets evaluated from file: 19040
# {
#     "index": 21,
#     "tweet_weekday": 5,
#     "tweet_day": 29,
#     "tweet_hour": 19,
#     "tweet_year": 2018,
#     "orig_text": "My \u2018me time\u2019 today consisted of cleaning the entire upstairs of my house and putting new sheets on the bed.",
#     "filtered_text": "my me time today consisted of cleaning the entire upstairs of my house and putting new sheets on the bed",
#     "user_ID": 19028194,
#     "user_verified": false,
#     "user_followers_count": 1286,
#     "user_friends_count": 1906,
#     "user_listed_count": 42,
#     "user_statuses_count": 40086,
#     "user_creation_year": 2009,
#     "user_creation_month": 1,
#     "user_creation_day": 15,
#     "place_name": "Calgary",
#     "place_province": "Alberta",
#     "place_country": "Canada",
#     "place_longitude": -114.316038,
#     "place_latitude": 50.84278,
#     "elapsed_time_in_days": 3635.3910069444446,
#     "label": null
# }
# Current tweets written from file: 21 , Total Tweets evaluated from file: 19837
# {
#     "index": 22,
#     "tweet_weekday": 5,
#     "tweet_day": 29,
#     "tweet_hour": 19,
#     "tweet_year": 2018,
#     "orig_text": "We ordered pizza for dinner and just put the baby to sleep and if it weren\u2019t for the freshly cleaned sheets I would\u2026 https://t.co/eVqJSeLE7A",
#     "filtered_text": "we ordered pizza for dinner and just put the baby to sleep and if it werent for the freshly cleaned sheets i would",
#     "user_ID": 19028194,
#     "user_verified": false,
#     "user_followers_count": 1286,
#     "user_friends_count": 1906,
#     "user_listed_count": 42,
#     "user_statuses_count": 40087,
#     "user_creation_year": 2009,
#     "user_creation_month": 1,
#     "user_creation_day": 15,
#     "place_name": "Calgary",
#     "place_province": "Alberta",
#     "place_country": "Canada",
#     "place_longitude": -114.316038,
#     "place_latitude": 50.84278,
#     "elapsed_time_in_days": 3635.3910069444446,
#     "label": null
# }
# Current tweets written from file: 22 , Total Tweets evaluated from file: 19863
# {
#     "index": 23,
#     "tweet_weekday": 5,
#     "tweet_day": 29,
#     "tweet_hour": 18,
#     "tweet_year": 2018,
#     "orig_text": "Forever grateful for the kindnesses that show up in my life!\u2800\n\u2800\nI have been so surrounded by love and beautiful, pe\u2026 https://t.co/UJWKJkDZaD",
#     "filtered_text": "forever grateful for the kindnesses that show up in my life i have been so surrounded by love and beautiful pe",
#     "user_ID": 141031985,
#     "user_verified": false,
#     "user_followers_count": 75,
#     "user_friends_count": 178,
#     "user_listed_count": 4,
#     "user_statuses_count": 3546,
#     "user_creation_year": 2010,
#     "user_creation_month": 5,
#     "user_creation_day": 7,
#     "place_name": "Prince George",
#     "place_province": "British Columbia",
#     "place_country": "Canada",
#     "place_longitude": -122.900929,
#     "place_latitude": 53.812891,
#     "elapsed_time_in_days": 3159.049849537037,
#     "label": null
# }
# Current tweets written from file: 23 , Total Tweets evaluated from file: 20713
# {
#     "index": 24,
#     "tweet_weekday": 5,
#     "tweet_day": 29,
#     "tweet_hour": 21,
#     "tweet_year": 2018,
#     "orig_text": "\u2018It's a good thing I was born a girl, otherwise I'd be a drag queen.\u2019 #DollyParton #Dumplin",
#     "filtered_text": "its a good thing i was born a girl otherwise id be a drag queen dollyparton dumplin",
#     "user_ID": 1467270660,
#     "user_verified": false,
#     "user_followers_count": 25,
#     "user_friends_count": 87,
#     "user_listed_count": 0,
#     "user_statuses_count": 448,
#     "user_creation_year": 2013,
#     "user_creation_month": 5,
#     "user_creation_day": 29,
#     "place_name": "Toronto",
#     "place_province": "Ontario",
#     "place_country": "Canada",
#     "place_longitude": -79.639319,
#     "place_latitude": 43.403221,
#     "elapsed_time_in_days": 2040.5257175925926,
#     "label": null
# }
# Current tweets written from file: 24 , Total Tweets evaluated from file: 20813
# {
#     "index": 25,
#     "tweet_weekday": 5,
#     "tweet_day": 29,
#     "tweet_hour": 21,
#     "tweet_year": 2018,
#     "orig_text": "So busy we barely had time to post!!! Tomorrow is the LAST NIGHT to catch us aurorafestto! Don\u2019t miss out!\u2026 https://t.co/euxeWGGAgE",
#     "filtered_text": "so busy we barely had time to post tomorrow is the last night to catch us aurorafestto dont NEG_miss NEG_out",
#     "user_ID": 1277517956,
#     "user_verified": false,
#     "user_followers_count": 766,
#     "user_friends_count": 569,
#     "user_listed_count": 87,
#     "user_statuses_count": 5384,
#     "user_creation_year": 2013,
#     "user_creation_month": 3,
#     "user_creation_day": 18,
#     "place_name": "Toronto",
#     "place_province": "Ontario",
#     "place_country": "Canada",
#     "place_longitude": -79.639319,
#     "place_latitude": 43.403221,
#     "elapsed_time_in_days": 2112.6057175925926,
#     "label": null
# }
# Current tweets written from file: 25 , Total Tweets evaluated from file: 21358
# {
#     "index": 26,
#     "tweet_weekday": 5,
#     "tweet_day": 29,
#     "tweet_hour": 20,
#     "tweet_year": 2018,
#     "orig_text": "My New Years resolution is to drink more beer",
#     "filtered_text": "my new years resolution is to drink more beer",
#     "user_ID": 411099170,
#     "user_verified": false,
#     "user_followers_count": 810,
#     "user_friends_count": 416,
#     "user_listed_count": 2,
#     "user_statuses_count": 26484,
#     "user_creation_year": 2011,
#     "user_creation_month": 11,
#     "user_creation_day": 13,
#     "place_name": "Brandon",
#     "place_province": "Manitoba",
#     "place_country": "Canada",
#     "place_longitude": -100.008104,
#     "place_latitude": 49.810856,
#     "elapsed_time_in_days": 2604.077083333333,
#     "label": null
# }
# Current tweets written from file: 26 , Total Tweets evaluated from file: 22796
# {
#     "index": 27,
#     "tweet_weekday": 5,
#     "tweet_day": 29,
#     "tweet_hour": 21,
#     "tweet_year": 2018,
#     "orig_text": "Better get more rest, you've got a busy weekend ahead. https://t.co/5S3VzgRUUd",
#     "filtered_text": "better get more rest youve got a busy weekend ahead",
#     "user_ID": 744712978713419800,
#     "user_verified": false,
#     "user_followers_count": 55,
#     "user_friends_count": 221,
#     "user_listed_count": 9,
#     "user_statuses_count": 828,
#     "user_creation_year": 2016,
#     "user_creation_month": 6,
#     "user_creation_day": 20,
#     "place_name": "Toronto",
#     "place_province": "Ontario",
#     "place_country": "Canada",
#     "place_longitude": -79.639319,
#     "place_latitude": 43.403221,
#     "elapsed_time_in_days": 923.0039930555555,
#     "label": null
# }
# Current tweets written from file: 27 , Total Tweets evaluated from file: 23100
# {
#     "index": 28,
#     "tweet_weekday": 5,
#     "tweet_day": 29,
#     "tweet_hour": 18,
#     "tweet_year": 2018,
#     "orig_text": "If I buy the $300 GoreTex bike jacket will the ads go away ?#notsosubliminaladvertising",
#     "filtered_text": "if i buy the 300 goretex bike jacket will the ads go away notsosubliminaladvertising",
#     "user_ID": 3274750914,
#     "user_verified": false,
#     "user_followers_count": 30,
#     "user_friends_count": 93,
#     "user_listed_count": 3,
#     "user_statuses_count": 300,
#     "user_creation_year": 2015,
#     "user_creation_month": 7,
#     "user_creation_day": 10,
#     "place_name": "Jasper",
#     "place_province": "Alberta",
#     "place_country": "Canada",
#     "place_longitude": -118.589337,
#     "place_latitude": 52.746767,
#     "elapsed_time_in_days": 1268.3020601851852,
#     "label": null
# }
# Current tweets written from file: 28 , Total Tweets evaluated from file: 23691
# {
#     "index": 29,
#     "tweet_weekday": 5,
#     "tweet_day": 29,
#     "tweet_hour": 21,
#     "tweet_year": 2018,
#     "orig_text": "I love Canada \ud83c\udde8\ud83c\udde6! Here at an Italian Restaurant celebrating the wedding of a colleague honouring both Sudanese/Cana\u2026 https://t.co/oetBE196Xt",
#     "filtered_text": "i love canada canada here at an italian restaurant celebrating the wedding of a colleague honouring both sudanesecana",
#     "user_ID": 2305475125,
#     "user_verified": false,
#     "user_followers_count": 1026,
#     "user_friends_count": 251,
#     "user_listed_count": 9,
#     "user_statuses_count": 1408,
#     "user_creation_year": 2014,
#     "user_creation_month": 1,
#     "user_creation_day": 22,
#     "place_name": "Toronto",
#     "place_province": "Ontario",
#     "place_country": "Canada",
#     "place_longitude": -79.639319,
#     "place_latitude": 43.403221,
#     "elapsed_time_in_days": 1802.2102662037034,
#     "label": null
# }
# Current tweets written from file: 29 , Total Tweets evaluated from file: 25215
# {
#     "index": 30,
#     "tweet_weekday": 5,
#     "tweet_day": 29,
#     "tweet_hour": 21,
#     "tweet_year": 2018,
#     "orig_text": "@greenhousenyt @fightfor15 Some hearts are cold. Winter doesn't help.",
#     "filtered_text": "at_greenhousenyt at_fightfor15 some hearts are cold winter doesnt NEG_help",
#     "user_ID": 163197616,
#     "user_verified": false,
#     "user_followers_count": 140,
#     "user_friends_count": 291,
#     "user_listed_count": 4,
#     "user_statuses_count": 6401,
#     "user_creation_year": 2010,
#     "user_creation_month": 7,
#     "user_creation_day": 5,
#     "place_name": "Cambridge",
#     "place_province": "Ontario",
#     "place_country": "Canada",
#     "place_longitude": -80.413946,
#     "place_latitude": 43.332161,
#     "elapsed_time_in_days": 3099.2519328703706,
#     "label": null
# }
# Current tweets written from file: 30 , Total Tweets evaluated from file: 26055
# {
#     "index": 31,
#     "tweet_weekday": 5,
#     "tweet_day": 29,
#     "tweet_hour": 23,
#     "tweet_year": 2018,
#     "orig_text": "@jeremyrumbolt OK you\u2019ve had enough young fella. Time for bed.",
#     "filtered_text": "at_jeremyrumbolt ok youve had enough young fella time for bed",
#     "user_ID": 456170579,
#     "user_verified": true,
#     "user_followers_count": 3156,
#     "user_friends_count": 777,
#     "user_listed_count": 66,
#     "user_statuses_count": 25793,
#     "user_creation_year": 2012,
#     "user_creation_month": 1,
#     "user_creation_day": 5,
#     "place_name": "St. John's",
#     "place_province": "Newfoundland and Labrador",
#     "place_country": "Canada",
#     "place_longitude": -53.039678,
#     "place_latitude": 47.330824,
#     "elapsed_time_in_days": 2550.115173611111,
#     "label": null
# }
# Current tweets written from file: 31 , Total Tweets evaluated from file: 26957
# {
#     "index": 32,
#     "tweet_weekday": 5,
#     "tweet_day": 29,
#     "tweet_hour": 19,
#     "tweet_year": 2018,
#     "orig_text": "Lemme be happy with my body. @ Self Love https://t.co/7IuvpMETWf",
#     "filtered_text": "lemme be happy with my body at self love",
#     "user_ID": 711798242,
#     "user_verified": false,
#     "user_followers_count": 478,
#     "user_friends_count": 476,
#     "user_listed_count": 3,
#     "user_statuses_count": 19927,
#     "user_creation_year": 2012,
#     "user_creation_month": 7,
#     "user_creation_day": 23,
#     "place_name": "Argentia Beach",
#     "place_province": "Alberta",
#     "place_country": "Canada",
#     "place_longitude": -114.038288,
#     "place_latitude": 53.047743,
#     "elapsed_time_in_days": 2350.9016550925926,
#     "label": null
# }
# Current tweets written from file: 32 , Total Tweets evaluated from file: 27050
# {
#     "index": 33,
#     "tweet_weekday": 5,
#     "tweet_day": 29,
#     "tweet_hour": 19,
#     "tweet_year": 2018,
#     "orig_text": "@MaxontheCoast I never get tired of that drive",
#     "filtered_text": "at_maxonthecoast i never NEG_get NEG_tired NEG_of NEG_that NEG_drive",
#     "user_ID": 1653705618,
#     "user_verified": false,
#     "user_followers_count": 744,
#     "user_friends_count": 1033,
#     "user_listed_count": 18,
#     "user_statuses_count": 31137,
#     "user_creation_year": 2013,
#     "user_creation_month": 8,
#     "user_creation_day": 7,
#     "place_name": "Calgary",
#     "place_province": "Alberta",
#     "place_country": "Canada",
#     "place_longitude": -114.316038,
#     "place_latitude": 50.84278,
#     "elapsed_time_in_days": 1970.2683564814813,
#     "label": null
# }
# Current tweets written from file: 33 , Total Tweets evaluated from file: 27734
# {
#     "index": 34,
#     "tweet_weekday": 5,
#     "tweet_day": 29,
#     "tweet_hour": 19,
#     "tweet_year": 2018,
#     "orig_text": "@CPC_HQ Schmeer you knumbskull the provinces control their resources and Trudeau is doing all he can to rectify con\u2026 https://t.co/ektF65ah6j",
#     "filtered_text": "at_cpc_hq schmeer you knumbskull the provinces control their resources and trudeau is doing all he can to rectify con",
#     "user_ID": 969630312262090800,
#     "user_verified": false,
#     "user_followers_count": 6,
#     "user_friends_count": 47,
#     "user_listed_count": 0,
#     "user_statuses_count": 1762,
#     "user_creation_year": 2018,
#     "user_creation_month": 3,
#     "user_creation_day": 2,
#     "place_name": "Calgary",
#     "place_province": "Alberta",
#     "place_country": "Canada",
#     "place_longitude": -114.316038,
#     "place_latitude": 50.84278,
#     "elapsed_time_in_days": 302.35148148148147,
#     "label": null
# }
# Current tweets written from file: 34 , Total Tweets evaluated from file: 27868
# {
#     "index": 35,
#     "tweet_weekday": 5,
#     "tweet_day": 29,
#     "tweet_hour": 21,
#     "tweet_year": 2018,
#     "orig_text": "@CityNews dealing with theft is normal for every person who works in a retail job. The union probably is more conce\u2026 https://t.co/RQQe20otmZ",
#     "filtered_text": "at_citynews dealing with theft is normal for every person who works in a retail job the union probably is more conce",
#     "user_ID": 19191036,
#     "user_verified": false,
#     "user_followers_count": 295,
#     "user_friends_count": 311,
#     "user_listed_count": 3,
#     "user_statuses_count": 3635,
#     "user_creation_year": 2009,
#     "user_creation_month": 1,
#     "user_creation_day": 19,
#     "place_name": "London",
#     "place_province": "Ontario",
#     "place_country": "Canada",
#     "place_longitude": -81.391247,
#     "place_latitude": 42.824496,
#     "elapsed_time_in_days": 3631.3809375,
#     "label": null
# }
# Current tweets written from file: 35 , Total Tweets evaluated from file: 27897
# {
#     "index": 36,
#     "tweet_weekday": 5,
#     "tweet_day": 29,
#     "tweet_hour": 21,
#     "tweet_year": 2018,
#     "orig_text": "Brrrrrr!  -18C Ottawa, cold and beautiful \ud83c\udf41\u2744\ufe0f\u2665\ufe0f @ City of Ottawa https://t.co/Rw3DVOrj4p",
#     "filtered_text": "brrrrrr 18c ottawa cold and beautiful emoji_maple_leaf emoji_snowflake emoji_heart_suit at city of ottawa",
#     "user_ID": 52096884,
#     "user_verified": false,
#     "user_followers_count": 351,
#     "user_friends_count": 368,
#     "user_listed_count": 58,
#     "user_statuses_count": 7704,
#     "user_creation_year": 2009,
#     "user_creation_month": 6,
#     "user_creation_day": 29,
#     "place_name": "Ottawa",
#     "place_province": "Ontario",
#     "place_country": "Canada",
#     "place_longitude": -76.353876,
#     "place_latitude": 44.961937,
#     "elapsed_time_in_days": 3470.4266666666667,
#     "label": null
# }
# Current tweets written from file: 36 , Total Tweets evaluated from file: 29279
# {
#     "index": 37,
#     "tweet_weekday": 5,
#     "tweet_day": 29,
#     "tweet_hour": 20,
#     "tweet_year": 2018,
#     "orig_text": "@Besaba27 We had bosses trying to cross the border with guns. They were turned away or they had to get rid of the g\u2026 https://t.co/A5sHMCpb6z",
#     "filtered_text": "at_besaba27 we had bosses trying to cross the border with guns they were turned away or they had to get rid of the g",
#     "user_ID": 848851628,
#     "user_verified": false,
#     "user_followers_count": 222,
#     "user_friends_count": 448,
#     "user_listed_count": 8,
#     "user_statuses_count": 14712,
#     "user_creation_year": 2012,
#     "user_creation_month": 9,
#     "user_creation_day": 27,
#     "place_name": "Winnipeg",
#     "place_province": "Manitoba",
#     "place_country": "Canada",
#     "place_longitude": -97.350366,
#     "place_latitude": 49.713679,
#     "elapsed_time_in_days": 2284.7658217592593,
#     "label": null
# }
# Current tweets written from file: 37 , Total Tweets evaluated from file: 30925
# {
#     "index": 38,
#     "tweet_weekday": 5,
#     "tweet_day": 29,
#     "tweet_hour": 19,
#     "tweet_year": 2018,
#     "orig_text": "@MacLeodLisa Tired of the lies and bullshit, I have to wonder what your getting for all your lies and deceit?\nBecau\u2026 https://t.co/IJ1NeoeiCz",
#     "filtered_text": "at_macleodlisa tired of the lies and bullshit i have to wonder what your getting for all your lies and deceit becau",
#     "user_ID": 162600984,
#     "user_verified": false,
#     "user_followers_count": 1657,
#     "user_friends_count": 2766,
#     "user_listed_count": 75,
#     "user_statuses_count": 98452,
#     "user_creation_year": 2010,
#     "user_creation_month": 7,
#     "user_creation_day": 4,
#     "place_name": "Sylvan Lake",
#     "place_province": "Alberta",
#     "place_country": "Canada",
#     "place_longitude": -114.121165,
#     "place_latitude": 52.282105,
#     "elapsed_time_in_days": 3100.9095833333336,
#     "label": null
# }
# Current tweets written from file: 38 , Total Tweets evaluated from file: 31285
# {
#     "index": 39,
#     "tweet_weekday": 5,
#     "tweet_day": 29,
#     "tweet_hour": 21,
#     "tweet_year": 2018,
#     "orig_text": "@beellabanks life\u2019s too short to say no",
#     "filtered_text": "at_beellabanks lifes too short to say no",
#     "user_ID": 964440570516078600,
#     "user_verified": false,
#     "user_followers_count": 26,
#     "user_friends_count": 50,
#     "user_listed_count": 0,
#     "user_statuses_count": 355,
#     "user_creation_year": 2018,
#     "user_creation_month": 2,
#     "user_creation_day": 16,
#     "place_name": "Montr\u00e9al",
#     "place_province": "Qu\u00e9bec",
#     "place_country": "Canada",
#     "place_longitude": -73.972965,
#     "place_latitude": 45.410095,
#     "elapsed_time_in_days": 316.6732638888889,
#     "label": null
# }
# Current tweets written from file: 39 , Total Tweets evaluated from file: 31444
# {
#     "index": 40,
#     "tweet_weekday": 5,
#     "tweet_day": 29,
#     "tweet_hour": 21,
#     "tweet_year": 2018,
#     "orig_text": "@OJessicaNigri The kind that makes you feel like you\u2019ve been punched in the ribs.",
#     "filtered_text": "at_ojessicanigri the kind that makes you feel like youve been punched in the ribs",
#     "user_ID": 70847003,
#     "user_verified": false,
#     "user_followers_count": 114,
#     "user_friends_count": 507,
#     "user_listed_count": 3,
#     "user_statuses_count": 2990,
#     "user_creation_year": 2009,
#     "user_creation_month": 9,
#     "user_creation_day": 2,
#     "place_name": "Cornwall",
#     "place_province": "Ontario",
#     "place_country": "Canada",
#     "place_longitude": -74.848169,
#     "place_latitude": 44.990428,
#     "elapsed_time_in_days": 3406.029432870371,
#     "label": null
# }
# Current tweets written from file: 40 , Total Tweets evaluated from file: 32262
# {
#     "index": 41,
#     "tweet_weekday": 5,
#     "tweet_day": 29,
#     "tweet_hour": 21,
#     "tweet_year": 2018,
#     "orig_text": "@BobTrek You might also want to pass on TEETH.",
#     "filtered_text": "at_bobtrek you might also want to pass on teeth",
#     "user_ID": 1167679248,
#     "user_verified": false,
#     "user_followers_count": 579,
#     "user_friends_count": 825,
#     "user_listed_count": 50,
#     "user_statuses_count": 13078,
#     "user_creation_year": 2013,
#     "user_creation_month": 2,
#     "user_creation_day": 11,
#     "place_name": "Toronto",
#     "place_province": "Ontario",
#     "place_country": "Canada",
#     "place_longitude": -79.639319,
#     "place_latitude": 43.403221,
#     "elapsed_time_in_days": 2147.9594328703706,
#     "label": null
# }
# Current tweets written from file: 41 , Total Tweets evaluated from file: 37605
# {
#     "index": 42,
#     "tweet_weekday": 5,
#     "tweet_day": 29,
#     "tweet_hour": 21,
#     "tweet_year": 2018,
#     "orig_text": "I swear my baby dads slow and or has a disorder",
#     "filtered_text": "i swear my baby dads slow and or has a disorder",
#     "user_ID": 4894035163,
#     "user_verified": false,
#     "user_followers_count": 889,
#     "user_friends_count": 387,
#     "user_listed_count": 42,
#     "user_statuses_count": 170347,
#     "user_creation_year": 2016,
#     "user_creation_month": 2,
#     "user_creation_day": 11,
#     "place_name": "Mississauga",
#     "place_province": "Ontario",
#     "place_country": "Canada",
#     "place_longitude": -79.810142,
#     "place_latitude": 43.373074,
#     "elapsed_time_in_days": 1052.2769560185186,
#     "label": null
# }
# Current tweets written from file: 42 , Total Tweets evaluated from file: 38557
# {
#     "index": 43,
#     "tweet_weekday": 5,
#     "tweet_day": 29,
#     "tweet_hour": 21,
#     "tweet_year": 2018,
#     "orig_text": "MY DAD WON HQ WOOOOOOO! ( I went to question 11 out of 12..)",
#     "filtered_text": "my dad won hq wooooooo i went to question 11 out of 12",
#     "user_ID": 127972057,
#     "user_verified": false,
#     "user_followers_count": 282,
#     "user_friends_count": 624,
#     "user_listed_count": 17,
#     "user_statuses_count": 5372,
#     "user_creation_year": 2010,
#     "user_creation_month": 3,
#     "user_creation_day": 30,
#     "place_name": "Toronto",
#     "place_province": "Ontario",
#     "place_country": "Canada",
#     "place_longitude": -79.639319,
#     "place_latitude": 43.403221,
#     "elapsed_time_in_days": 3196.296261574074,
#     "label": null
# }
# Current tweets written from file: 43 , Total Tweets evaluated from file: 38844
# {
#     "index": 44,
#     "tweet_weekday": 5,
#     "tweet_day": 29,
#     "tweet_hour": 21,
#     "tweet_year": 2018,
#     "orig_text": "Went to the dollars store and got a bunch of body wash and lotion. All my real ones in Jamaica getting one when I'm back \ud83d\ude02",
#     "filtered_text": "went to the dollars store and got a bunch of body wash and lotion all my real ones in jamaica getting one when im back emoji_face_with_tears_of_joy",
#     "user_ID": 42509876,
#     "user_verified": false,
#     "user_followers_count": 1972,
#     "user_friends_count": 787,
#     "user_listed_count": 43,
#     "user_statuses_count": 117000,
#     "user_creation_year": 2009,
#     "user_creation_month": 5,
#     "user_creation_day": 25,
#     "place_name": "Oshawa",
#     "place_province": "Ontario",
#     "place_country": "Canada",
#     "place_longitude": -78.959206,
#     "place_latitude": 43.614586,
#     "elapsed_time_in_days": 3505.1292708333335,
#     "label": null
# }
# Current tweets written from file: 44 , Total Tweets evaluated from file: 40003
# {
#     "index": 45,
#     "tweet_weekday": 5,
#     "tweet_day": 29,
#     "tweet_hour": 21,
#     "tweet_year": 2018,
#     "orig_text": "Look at who\u2019s staring the PP. nice work, Babcock.",
#     "filtered_text": "look at whos staring the pp nice work babcock",
#     "user_ID": 1692519312,
#     "user_verified": false,
#     "user_followers_count": 1328,
#     "user_friends_count": 1010,
#     "user_listed_count": 60,
#     "user_statuses_count": 80084,
#     "user_creation_year": 2013,
#     "user_creation_month": 8,
#     "user_creation_day": 23,
#     "place_name": "Toronto",
#     "place_province": "Ontario",
#     "place_country": "Canada",
#     "place_longitude": -79.639319,
#     "place_latitude": 43.403221,
#     "elapsed_time_in_days": 1955.0323379629633,
#     "label": null
# }
# Current tweets written from file: 45 , Total Tweets evaluated from file: 40424
# {
#     "index": 46,
#     "tweet_weekday": 5,
#     "tweet_day": 29,
#     "tweet_hour": 21,
#     "tweet_year": 2018,
#     "orig_text": "@GordonLeenders @RALPH_RE @bigbenji91 \u2022Shots fired\u2022",
#     "filtered_text": "at_gordonleenders at_ralph_re at_bigbenji91 shots fired",
#     "user_ID": 29239678,
#     "user_verified": false,
#     "user_followers_count": 3706,
#     "user_friends_count": 2673,
#     "user_listed_count": 68,
#     "user_statuses_count": 128868,
#     "user_creation_year": 2009,
#     "user_creation_month": 4,
#     "user_creation_day": 6,
#     "place_name": "Richmond Hill",
#     "place_province": "Ontario",
#     "place_country": "Canada",
#     "place_longitude": -79.485633,
#     "place_latitude": 43.829311,
#     "elapsed_time_in_days": 3554.3910300925922,
#     "label": null
# }
# Current tweets written from file: 46 , Total Tweets evaluated from file: 41398
# {
#     "index": 47,
#     "tweet_weekday": 5,
#     "tweet_day": 29,
#     "tweet_hour": 21,
#     "tweet_year": 2018,
#     "orig_text": "Man oh man I can feel my age fading away",
#     "filtered_text": "man oh man i can feel my age fading away",
#     "user_ID": 1915052473,
#     "user_verified": false,
#     "user_followers_count": 220,
#     "user_friends_count": 171,
#     "user_listed_count": 1,
#     "user_statuses_count": 2816,
#     "user_creation_year": 2013,
#     "user_creation_month": 9,
#     "user_creation_day": 28,
#     "place_name": "Toronto",
#     "place_province": "Ontario",
#     "place_country": "Canada",
#     "place_longitude": -79.639319,
#     "place_latitude": 43.403221,
#     "elapsed_time_in_days": 1918.3073148148148,
#     "label": null
# }
# Current tweets written from file: 47 , Total Tweets evaluated from file: 41834
# {
#     "index": 48,
#     "tweet_weekday": 5,
#     "tweet_day": 29,
#     "tweet_hour": 20,
#     "tweet_year": 2018,
#     "orig_text": "@abprogressive @trishkatree @roy_maclellan @Cdn4LFC @jkenney @AndrewScheer Hahaha \u201c a bible school dropout\u201dOMG  the shame!!!!!",
#     "filtered_text": "at_abprogressive at_trishkatree at_roy_maclellan at_cdn4lfc at_jkenney at_andrewscheer hahaha a bible school dropoutomg the shame",
#     "user_ID": 831691644667781100,
#     "user_verified": false,
#     "user_followers_count": 305,
#     "user_friends_count": 204,
#     "user_listed_count": 2,
#     "user_statuses_count": 17028,
#     "user_creation_year": 2017,
#     "user_creation_month": 2,
#     "user_creation_day": 15,
#     "place_name": "Hazlet",
#     "place_province": "Saskatchewan",
#     "place_country": "Canada",
#     "place_longitude": -108.599102,
#     "place_latitude": 50.396187,
#     "elapsed_time_in_days": 682.9932175925925,
#     "label": null
# }
# Current tweets written from file: 48 , Total Tweets evaluated from file: 43040
# {
#     "index": 49,
#     "tweet_weekday": 5,
#     "tweet_day": 29,
#     "tweet_hour": 21,
#     "tweet_year": 2018,
#     "orig_text": "Nice work Marleau.",
#     "filtered_text": "nice work marleau",
#     "user_ID": 1692519312,
#     "user_verified": false,
#     "user_followers_count": 1328,
#     "user_friends_count": 1010,
#     "user_listed_count": 60,
#     "user_statuses_count": 80085,
#     "user_creation_year": 2013,
#     "user_creation_month": 8,
#     "user_creation_day": 23,
#     "place_name": "Toronto",
#     "place_province": "Ontario",
#     "place_country": "Canada",
#     "place_longitude": -79.639319,
#     "place_latitude": 43.403221,
#     "elapsed_time_in_days": 1955.0332060185185,
#     "label": null
# }
# Current tweets written from file: 49 , Total Tweets evaluated from file: 44144
# {
#     "index": 50,
#     "tweet_weekday": 5,
#     "tweet_day": 29,
#     "tweet_hour": 21,
#     "tweet_year": 2018,
#     "orig_text": "Black women are so beautiful I thank God for life for being in the same dimension as them",
#     "filtered_text": "black women are so beautiful i thank god for life for being in the same dimension as them",
#     "user_ID": 993997000923213800,
#     "user_verified": false,
#     "user_followers_count": 312,
#     "user_friends_count": 355,
#     "user_listed_count": 2,
#     "user_statuses_count": 21181,
#     "user_creation_year": 2018,
#     "user_creation_month": 5,
#     "user_creation_day": 8,
#     "place_name": "Toronto",
#     "place_province": "Ontario",
#     "place_country": "Canada",
#     "place_longitude": -79.639319,
#     "place_latitude": 43.403221,
#     "elapsed_time_in_days": 235.11628472222222,
#     "label": null
# }
# Current tweets written from file: 50 , Total Tweets evaluated from file: 45341
# {
#     "index": 51,
#     "tweet_weekday": 5,
#     "tweet_day": 29,
#     "tweet_hour": 21,
#     "tweet_year": 2018,
#     "orig_text": "I littlery feel like I\u2019m dying from the amount of alcohol i drank tonight",
#     "filtered_text": "i littlery feel like im dying from the amount of alcohol i drank tonight",
#     "user_ID": 872307345463881700,
#     "user_verified": false,
#     "user_followers_count": 163,
#     "user_friends_count": 439,
#     "user_listed_count": 2,
#     "user_statuses_count": 6257,
#     "user_creation_year": 2017,
#     "user_creation_month": 6,
#     "user_creation_day": 7,
#     "place_name": "Hamilton",
#     "place_province": "Ontario",
#     "place_country": "Canada",
#     "place_longitude": -80.248423,
#     "place_latitude": 43.050553,
#     "elapsed_time_in_days": 570.9158912037036,
#     "label": null
# }
# Current tweets written from file: 51 , Total Tweets evaluated from file: 45909
# {
#     "index": 52,
#     "tweet_weekday": 5,
#     "tweet_day": 29,
#     "tweet_hour": 19,
#     "tweet_year": 2018,
#     "orig_text": "@PFF After a win vs Kansas City only #10? Keep sleeping \ud83d\udca4",
#     "filtered_text": "at_pff after a win vs kansas city only 10 keep sleeping emoji_zzz",
#     "user_ID": 246181360,
#     "user_verified": false,
#     "user_followers_count": 476,
#     "user_friends_count": 971,
#     "user_listed_count": 4,
#     "user_statuses_count": 14865,
#     "user_creation_year": 2011,
#     "user_creation_month": 2,
#     "user_creation_day": 2,
#     "place_name": "Parkland County",
#     "place_province": "Alberta",
#     "place_country": "Canada",
#     "place_longitude": -115.118937,
#     "place_latitude": 53.303584,
#     "elapsed_time_in_days": 2887.7113773148144,
#     "label": null
# }
# Current tweets written from file: 52 , Total Tweets evaluated from file: 46689
# {
#     "index": 53,
#     "tweet_weekday": 5,
#     "tweet_day": 29,
#     "tweet_hour": 21,
# ...
#     "tweet_hour": 21,
#     "tweet_year": 2018,
#     "orig_text": "East York Apartments for rent on https://t.co/rc0bRnWlUZ https://t.co/nYml8oc6nQ",
#     "filtered_text": "east york apartments for rent on",
#     "user_ID": 31169027,
#     "user_verified": false,
#     "user_followers_count": 345,
#     "user_friends_count": 0,
#     "user_listed_count": 33,
#     "user_statuses_count": 189592,
#     "user_creation_year": 2009,
#     "user_creation_month": 4,
#     "user_creation_day": 14,
#     "place_name": "Toronto",
#     "place_province": "Ontario",
#     "place_country": "Canada",
#     "place_longitude": -79.639319,
#     "place_latitude": 43.403221,
#     "elapsed_time_in_days": 3546.390335648148,
#     "label": null
# }
# Current tweets written from file: 103 , Total Tweets evaluated from file: 76840
# {
#     "index": 104,
#     "tweet_weekday": 5,
#     "tweet_day": 29,
#     "tweet_hour": 21,
#     "tweet_year": 2018,
#     "orig_text": "Kitchener Apartments for rent on https://t.co/rc0bRnWlUZ https://t.co/RxZOJ2Bl8K",
#     "filtered_text": "kitchener apartments for rent on",
#     "user_ID": 31169027,
#     "user_verified": false,
#     "user_followers_count": 345,
#     "user_friends_count": 0,
#     "user_listed_count": 33,
#     "user_statuses_count": 189595,
#     "user_creation_year": 2009,
#     "user_creation_month": 4,
#     "user_creation_day": 14,
#     "place_name": "Kitchener",
#     "place_province": "Ontario",
#     "place_country": "Canada",
#     "place_longitude": -80.574116,
#     "place_latitude": 43.353845,
#     "elapsed_time_in_days": 3546.390335648148,
#     "label": null
# }
# Current tweets written from file: 104 , Total Tweets evaluated from file: 76859
# {
#     "index": 105,
#     "tweet_weekday": 5,
#     "tweet_day": 29,
#     "tweet_hour": 21,
#     "tweet_year": 2018,
#     "orig_text": "London Apartments for rent on https://t.co/rc0bRnWlUZ https://t.co/9eVJEatyNt",
#     "filtered_text": "london apartments for rent on",
#     "user_ID": 31169027,
#     "user_verified": false,
#     "user_followers_count": 345,
#     "user_friends_count": 0,
#     "user_listed_count": 33,
#     "user_statuses_count": 189596,
#     "user_creation_year": 2009,
#     "user_creation_month": 4,
#     "user_creation_day": 14,
#     "place_name": "London",
#     "place_province": "Ontario",
#     "place_country": "Canada",
#     "place_longitude": -81.391247,
#     "place_latitude": 42.824496,
#     "elapsed_time_in_days": 3546.390335648148,
#     "label": null
# }
# Current tweets written from file: 105 , Total Tweets evaluated from file: 76867
# {
#     "index": 106,
#     "tweet_weekday": 5,
#     "tweet_day": 29,
#     "tweet_hour": 21,
#     "tweet_year": 2018,
#     "orig_text": "North Bay Apartments for rent on https://t.co/rc0bRnWlUZ https://t.co/rD26gRGhy1",
#     "filtered_text": "north bay apartments for rent on",
#     "user_ID": 31169027,
#     "user_verified": false,
#     "user_followers_count": 345,
#     "user_friends_count": 0,
#     "user_listed_count": 33,
#     "user_statuses_count": 189598,
#     "user_creation_year": 2009,
#     "user_creation_month": 4,
#     "user_creation_day": 14,
#     "place_name": "North Bay",
#     "place_province": "Ontario",
#     "place_country": "Canada",
#     "place_longitude": -79.505086,
#     "place_latitude": 46.222736,
#     "elapsed_time_in_days": 3546.3903472222223,
#     "label": null
# }
# Current tweets written from file: 106 , Total Tweets evaluated from file: 76884
# {
#     "index": 107,
#     "tweet_weekday": 5,
#     "tweet_day": 29,
#     "tweet_hour": 21,
#     "tweet_year": 2018,
#     "orig_text": "North York Apartments for rent on https://t.co/rc0bRnWlUZ https://t.co/2FQez3NfcC",
#     "filtered_text": "north york apartments for rent on",
#     "user_ID": 31169027,
#     "user_verified": false,
#     "user_followers_count": 345,
#     "user_friends_count": 0,
#     "user_listed_count": 33,
#     "user_statuses_count": 189599,
#     "user_creation_year": 2009,
#     "user_creation_month": 4,
#     "user_creation_day": 14,
#     "place_name": "Toronto",
#     "place_province": "Ontario",
#     "place_country": "Canada",
#     "place_longitude": -79.639319,
#     "place_latitude": 43.403221,
#     "elapsed_time_in_days": 3546.3903472222223,
#     "label": null
# }
# Current tweets written from file: 107 , Total Tweets evaluated from file: 76894
# {
#     "index": 108,
#     "tweet_weekday": 5,
#     "tweet_day": 29,
#     "tweet_hour": 21,
#     "tweet_year": 2018,
#     "orig_text": "Ottawa Houses for rent on https://t.co/rc0bRnWlUZ https://t.co/UEiFly8187",
#     "filtered_text": "ottawa houses for rent on",
#     "user_ID": 31169027,
#     "user_verified": false,
#     "user_followers_count": 345,
#     "user_friends_count": 0,
#     "user_listed_count": 33,
#     "user_statuses_count": 189602,
#     "user_creation_year": 2009,
#     "user_creation_month": 4,
#     "user_creation_day": 14,
#     "place_name": "Ottawa",
#     "place_province": "Ontario",
#     "place_country": "Canada",
#     "place_longitude": -76.353876,
#     "place_latitude": 44.961937,
#     "elapsed_time_in_days": 3546.3903472222223,
#     "label": null
# }
# Current tweets written from file: 108 , Total Tweets evaluated from file: 76903
# {
#     "index": 109,
#     "tweet_weekday": 5,
#     "tweet_day": 29,
#     "tweet_hour": 21,
#     "tweet_year": 2018,
#     "orig_text": "Owen Sound Apartments for rent on https://t.co/rc0bRnWlUZ https://t.co/QASk9xsy4Q",
#     "filtered_text": "owen sound apartments for rent on",
#     "user_ID": 31169027,
#     "user_verified": false,
#     "user_followers_count": 345,
#     "user_friends_count": 0,
#     "user_listed_count": 33,
#     "user_statuses_count": 189603,
#     "user_creation_year": 2009,
#     "user_creation_month": 4,
#     "user_creation_day": 14,
#     "place_name": "Owen Sound",
#     "place_province": "Ontario",
#     "place_country": "Canada",
#     "place_longitude": -80.963518,
#     "place_latitude": 44.540952,
#     "elapsed_time_in_days": 3546.3903472222223,
#     "label": null
# }
# Current tweets written from file: 109 , Total Tweets evaluated from file: 76908
# {
#     "index": 110,
#     "tweet_weekday": 5,
#     "tweet_day": 29,
#     "tweet_hour": 21,
#     "tweet_year": 2018,
#     "orig_text": "Richmond Hill Apartments for rent on https://t.co/rc0bRnEKwp https://t.co/9K7YspGaJj",
#     "filtered_text": "richmond hill apartments for rent on",
#     "user_ID": 31169027,
#     "user_verified": false,
#     "user_followers_count": 345,
#     "user_friends_count": 0,
#     "user_listed_count": 33,
#     "user_statuses_count": 189604,
#     "user_creation_year": 2009,
#     "user_creation_month": 4,
#     "user_creation_day": 14,
#     "place_name": "Richmond Hill",
#     "place_province": "Ontario",
#     "place_country": "Canada",
#     "place_longitude": -79.485633,
#     "place_latitude": 43.829311,
#     "elapsed_time_in_days": 3546.390358796296,
#     "label": null
# }
# Current tweets written from file: 110 , Total Tweets evaluated from file: 76916
# {
#     "index": 111,
#     "tweet_weekday": 5,
#     "tweet_day": 29,
#     "tweet_hour": 21,
#     "tweet_year": 2018,
#     "orig_text": "Sault Ste. Marie Apartments for rent on https://t.co/rc0bRnWlUZ https://t.co/wjE6luzmYL",
#     "filtered_text": "sault ste marie apartments for rent on",
#     "user_ID": 31169027,
#     "user_verified": false,
#     "user_followers_count": 345,
#     "user_friends_count": 0,
#     "user_listed_count": 33,
#     "user_statuses_count": 189605,
#     "user_creation_year": 2009,
#     "user_creation_month": 4,
#     "user_creation_day": 14,
#     "place_name": "Sault Ste. Marie",
#     "place_province": "Ontario",
#     "place_country": "Canada",
#     "place_longitude": -84.627477,
#     "place_latitude": 46.452865,
#     "elapsed_time_in_days": 3546.390358796296,
#     "label": null
# }
# Current tweets written from file: 111 , Total Tweets evaluated from file: 76934
# {
#     "index": 112,
#     "tweet_weekday": 5,
#     "tweet_day": 29,
#     "tweet_hour": 21,
#     "tweet_year": 2018,
#     "orig_text": "Scarborough Apartments for rent on https://t.co/rc0bRnWlUZ https://t.co/QXLEXPcVjR",
#     "filtered_text": "scarborough apartments for rent on",
#     "user_ID": 31169027,
#     "user_verified": false,
#     "user_followers_count": 345,
#     "user_friends_count": 0,
#     "user_listed_count": 33,
#     "user_statuses_count": 189606,
#     "user_creation_year": 2009,
#     "user_creation_month": 4,
#     "user_creation_day": 14,
#     "place_name": "Toronto",
#     "place_province": "Ontario",
#     "place_country": "Canada",
#     "place_longitude": -79.639319,
#     "place_latitude": 43.403221,
#     "elapsed_time_in_days": 3546.390358796296,
#     "label": null
# }
# Current tweets written from file: 112 , Total Tweets evaluated from file: 76943
# {
#     "index": 113,
#     "tweet_weekday": 5,
#     "tweet_day": 29,
#     "tweet_hour": 21,
#     "tweet_year": 2018,
#     "orig_text": "Toronto Apartments for rent on https://t.co/rc0bRnWlUZ https://t.co/08jm645Az1",
#     "filtered_text": "toronto apartments for rent on",
#     "user_ID": 31169027,
#     "user_verified": false,
#     "user_followers_count": 345,
#     "user_friends_count": 0,
#     "user_listed_count": 33,
#     "user_statuses_count": 189609,
#     "user_creation_year": 2009,
#     "user_creation_month": 4,
#     "user_creation_day": 14,
#     "place_name": "Toronto",
#     "place_province": "Ontario",
#     "place_country": "Canada",
#     "place_longitude": -79.639319,
#     "place_latitude": 43.403221,
#     "elapsed_time_in_days": 3546.390358796296,
#     "label": null
# }
# Current tweets written from file: 113 , Total Tweets evaluated from file: 76959
# {
#     "index": 114,
#     "tweet_weekday": 5,
#     "tweet_day": 29,
#     "tweet_hour": 21,
#     "tweet_year": 2018,
#     "orig_text": "Waterloo Apartments for rent on https://t.co/rc0bRnWlUZ https://t.co/X4tu13t8PA",
#     "filtered_text": "waterloo apartments for rent on",
#     "user_ID": 31169027,
#     "user_verified": false,
#     "user_followers_count": 345,
#     "user_friends_count": 0,
#     "user_listed_count": 33,
#     "user_statuses_count": 189610,
#     "user_creation_year": 2009,
#     "user_creation_month": 4,
#     "user_creation_day": 14,
#     "place_name": "Waterloo",
#     "place_province": "Ontario",
#     "place_country": "Canada",
#     "place_longitude": -80.626184,
#     "place_latitude": 43.432944,
#     "elapsed_time_in_days": 3546.390358796296,
#     "label": null
# }
# Current tweets written from file: 114 , Total Tweets evaluated from file: 76967
# {
#     "index": 115,
#     "tweet_weekday": 5,
#     "tweet_day": 29,
#     "tweet_hour": 21,
#     "tweet_year": 2018,
#     "orig_text": "Whitby Apartments for rent on https://t.co/rc0bRnWlUZ https://t.co/Qsl1ufV7X9",
#     "filtered_text": "whitby apartments for rent on",
#     "user_ID": 31169027,
#     "user_verified": false,
#     "user_followers_count": 345,
#     "user_friends_count": 0,
#     "user_listed_count": 33,
#     "user_statuses_count": 189611,
#     "user_creation_year": 2009,
#     "user_creation_month": 4,
#     "user_creation_day": 14,
#     "place_name": "Whitby",
#     "place_province": "Ontario",
#     "place_country": "Canada",
#     "place_longitude": -79.047315,
#     "place_latitude": 43.589036,
#     "elapsed_time_in_days": 3546.390370370371,
#     "label": null
# }
# Current tweets written from file: 115 , Total Tweets evaluated from file: 76978
# {
#     "index": 116,
#     "tweet_weekday": 5,
#     "tweet_day": 29,
#     "tweet_hour": 21,
#     "tweet_year": 2018,
#     "orig_text": "@Phoebe_Toronto Stunning  \ud83d\udc9e\ud83d\udc9e\ud83d\udc9d\ud83d\udc9d\ud83d\udc98\ud83d\udc98\ud83d\udc98\ud83d\udc98 \ud83d\udc9e\ud83d\udc9eGood night \ud83d\udca4\ud83d\ude34\ud83c\udf03\ud83c\udf0c\ud83c\udf1a\ud83d\udc4a\ud83c\udffd\ud83d\udc4a\ud83c\udffd \ud83d\ude18\ud83d\ude18\ud83d\ude18\ud83d\ude18",
#     "filtered_text": "at_phoebe_toronto stunning emoji_revolving_hearts emoji_revolving_hearts emoji_heart_with_ribbon emoji_heart_with_ribbon emoji_heart_with_arrow emoji_heart_with_arrow emoji_heart_with_arrow emoji_heart_with_arrow emoji_revolving_hearts emoji_revolving_hearts good night emoji_zzz emoji_sleeping_face emoji_night_with_stars emoji_milky_way emoji_new_moon_face emoji_oncoming_fist emoji_oncoming_fist emoji_face_blowing_a_kiss emoji_face_blowing_a_kiss emoji_face_blowing_a_kiss emoji_face_blowing_a_kiss",
#     "user_ID": 876935941469950000,
#     "user_verified": false,
#     "user_followers_count": 398,
#     "user_friends_count": 1553,
#     "user_listed_count": 0,
#     "user_statuses_count": 25175,
#     "user_creation_year": 2017,
#     "user_creation_month": 6,
#     "user_creation_day": 19,
#     "place_name": "Montr\u00e9al",
#     "place_province": "Qu\u00e9bec",
#     "place_country": "Canada",
#     "place_longitude": -73.972965,
#     "place_latitude": 45.410095,
#     "elapsed_time_in_days": 558.1508564814815,
#     "label": null
# }
# Current tweets written from file: 116 , Total Tweets evaluated from file: 77997
# {
#     "index": 117,
#     "tweet_weekday": 5,
#     "tweet_day": 29,
#     "tweet_hour": 18,
#     "tweet_year": 2018,
#     "orig_text": "Five minutes left in the second period and the Canadian party goes on! @5twisty5 got the pass close to the net and\u2026 https://t.co/Nd9z5aKwR6",
#     "filtered_text": "five minutes left in the second period and the canadian party goes on at_5twisty5 got the pass close to the net and",
#     "user_ID": 34895713,
#     "user_verified": true,
#     "user_followers_count": 144520,
#     "user_friends_count": 383,
#     "user_listed_count": 1677,
#     "user_statuses_count": 21342,
#     "user_creation_year": 2009,
#     "user_creation_month": 4,
#     "user_creation_day": 24,
#     "place_name": "Vancouver",
#     "place_province": "British Columbia",
#     "place_country": "Canada",
#     "place_longitude": -123.224215,
#     "place_latitude": 49.19854,
#     "elapsed_time_in_days": 3536.661145833333,
#     "label": null
# }
# Current tweets written from file: 117 , Total Tweets evaluated from file: 78414
# {
#     "index": 118,
#     "tweet_weekday": 5,
#     "tweet_day": 29,
#     "tweet_hour": 20,
#     "tweet_year": 2018,
#     "orig_text": "Take the body Habs.",
#     "filtered_text": "take the body habs",
#     "user_ID": 138051453,
#     "user_verified": false,
#     "user_followers_count": 837,
#     "user_friends_count": 438,
#     "user_listed_count": 72,
#     "user_statuses_count": 69045,
#     "user_creation_year": 2010,
#     "user_creation_month": 4,
#     "user_creation_day": 28,
#     "place_name": "Winnipeg",
#     "place_province": "Manitoba",
#     "place_country": "Canada",
#     "place_longitude": -97.350366,
#     "place_latitude": 49.713679,
#     "elapsed_time_in_days": 3167.5217592592594,
#     "label": null
# }
# Current tweets written from file: 118 , Total Tweets evaluated from file: 79295
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-39e49261ebbf> in <module>()
#     359     with open(output_filename, 'w', encoding='utf8') as outputFile:  # Open output file
#     360         for (i, line) in enumerate(f, 1):  # Iterate through each line in input file.
# --> 361             tweet_dict = json.loads(line)  # Load the .json object into a dictionary.
#     362             try:
#     363                 if filterTweet(tweet_dict, "en", "Canada"):  # Filter the tweet.
#
# /global/software/jupyterhub-spark/anaconda3/lib/python3.7/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# /global/software/jupyterhub-spark/anaconda3/lib/python3.7/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# /global/software/jupyterhub-spark/anaconda3/lib/python3.7/json/decoder.py in raw_decode(self, s, idx)
#     351         """
#     352         try:
# --> 353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
#     355             raise JSONDecodeError("Expecting value", s, err.value) from None
#
# KeyboardInterrupt:
